# %%
from bokeh.plotting import figure
from bokeh.io import output_file, output_notebook, show
from bokeh.sampledata.iris import flowers
from bokeh.layouts import gridplot
from bokeh.models import Range1d, PanTool, ResetTool, HoverTool, ColumnDataSource, LabelSet, Span, BoxAnnotation

# %%
# Defining the output file path
# output_file("S3.4-iris2.html")
output_notebook()

# %%
# Create the figure object
f = figure()

# %% [markdown]
# ##### Choose Plotting type

# %%
##### figure's Plotting Method #####
### Line Style Plotting ###
f.line#()
f.multi_line#()
f.hline_stack#()
f.vline_stack#()
f.step#()
f.segment#()
# -  -  -  -  -  -  -  -
### Bar Style Plotting ###
f.hbar#()
f.hbar_stack#()
f.vbar#()
f.vbar_stack#()
f.harea#()
f.harea_stack#()
f.varea#()
f.varea_stack#()
# -  -  -  -  -  -  -  -
### Dot Style Plotting ###
f.dot#()
f.text#()
f.image#()
f.image_rgba#()
f.image_url#()
# -  -  -  -  -  -  -  -
f.x#()
f.y#()
f.scatter#()
# -  -  -  -  -  -  -  -
f.asterisk#()
f.bezier#()
f.circle#()
f.circle_dot#()
f.circle_x#()
f.circle_y#()
f.circle_cross#()
f.cross#()
f.dash#()
f.diamond#()
f.diamond_cross#()
f.diamond_dot#()
#f.oval()
f.plus#()
f.triangle#()
f.triangle_dot#()
f.triangle_pin#()
f.inverted_triangle#()
f.patch#()
f.patches#()
f.square#()
f.square_cross#()
f.square_dot#()
f.square_pin#()
f.square_x#()
f.star#()
f.star_dot#()
# -  -  -  -  -  -  -  -
### ??? ###
f.annular_wedge#()
f.annulus#()
f.arc#()
f.ellipse#()
f.hex#()
f.hex_tile#()
f.hexbin#()
f.ray#()
f.multi_polygons#()
f.rect#()
f.quad#()
f.quadratic#()
f.wedge#()

f.circle(x=flowers['petal_length'],
         y=flowers['petal_width'],
         legend_label="Objects")

# %% [markdown]
# #### Style the plot area

# %%
##### figure :: Attributes #####
# Style the plot area
"x_range = DataRange1d(id='p1050', ...)"
"x_scale = LinearScale(id='p1062', ...)"
'extra_x_ranges = {}'
'extra_x_scales = {}'
# -  -  -  -  -  -  -  -
"y_range = DataRange1d(id='p1051', ...)"
"y_scale = LinearScale(id='p1064', ...)"
'extra_y_ranges = {}'
'extra_y_scales = {}'
 # -  -  -  -  -  -  -  -
'title_location = above'
 # -  -  -  -  -  -  -  -
'width = 600'
'height = 600'
'background_fill_color = #ffffff'
'background_fill_alpha = 1.0'
 # -  -  -  -  -  -  -  -
'border_fill_color = #ffffff'
'border_fill_alpha = 1.0'
 # -  -  -  -  -  -  -  -
'frame_width = None'
'frame_height = None'
 # -  -  -  -  -  -  -  -
'inner_width = 0'
'inner_height = 0'
 # -  -  -  -  -  -  -  -
'outer_width = 0'
'outer_height = 0'
 # -  -  -  -  -  -  -  -
'outline_line_color = #e5e5e5'
'outline_line_alpha = 1.0'
'outline_line_cap = butt'
'outline_line_dash = []'
'outline_line_dash_offset = 0'
'outline_line_join = bevel'
'outline_line_width = 1'
 # -  -  -  -  -  -  -  -
'min_border = 5'
'min_border_top = None'
'min_border_bottom = None'
'min_border_left = None'
'min_border_right = None'
 # -  -  -  -  -  -  -  -
'renderers = []'
# A list of all renderers for the plot, including guides and annotations in addition to glyphs
"left = [LinearAxis(id='p1073', ...)]"
'right = []'
'above = []'
"below = [LinearAxis(id='p1066', ...)]"
"center = [Grid(id='p1072', ...), Grid(id='p1079', ...)]"
# -  -  -  -  -  -  -  -
'hidpi = True'
# -  -  -  -  -  -  -  -
'lod_factor = 10'
'lod_threshold = 2000'
'lod_timeout = 500'
'output_backend = canvas'
'match_aspect = False'
'aspect_scale = 1'
'reset_policy = standard'
# -  -  -  -  -  -  -  -
# Style the plot area
"tools = [PanTool(id='p1080', ...), WheelZoomTool(id='p1081', ...), BoxZoomTool(id='p1082', ...), SaveTool(id='p1084', ...), ResetTool(id='p1085', ...), HelpTool(id='p1086', ...)]"
"toolbar = Toolbar(id='p1054', ...)"
'toolbar_location = right'
'toolbar_sticky = True'
"toolbar.logo = True"
# Out:
# 'reset_policy = standard'

# %% [markdown]
# #### Style the axes

# %%
# figure.axis:: Attributes
x = f.xaxis  # x-axis
y = f.yaxis  # y-axis
z = f.axis   # x,y axes

'bounds = auto'
#x.bounds = (2, 6)
#"ticker = BasicTicker(id='p1360', ...)"
#x[0].ticker.desired_num_ticks = 2
#y[0].ticker.desired_num_ticks = 2
#y[0].ticker.num_minor_ticks = 10

"ticker = BasicTicker(id='p1360', ...)"
"formatter = BasicTickFormatter(id='p1361', ...)"
# -  -  -  -  -  -  -  -
'axis_label = None'
'axis_label_standoff = 5'
'axis_label_text_color = #444444'
'axis_label_text_alpha = 1.0'
'axis_label_text_align = left'
'axis_label_text_font = helvetica'
'axis_label_text_font_size = 13px'
'axis_label_text_font_style = italic'
'axis_label_text_line_height = 1.2'
# -  -  -  -  -  -  -  -
'major_label_orientation = horizontal'
'major_label_overrides = {}'
"major_label_policy = AllLabels(id='p1359', ...)"
'major_label_text_color = #444444'
'major_label_text_alpha = 1.0'
'major_label_text_font = helvetica'
'major_label_text_font_size = 11px'
'major_label_text_font_style = normal'
'major_label_text_baseline = alphabetic'
'major_label_text_align = center'
'major_label_text_line_height = 1.2'
# -  -  -  -  -  -  -  -
'major_tick_in = 2' # The distance in pixels that major ticks should extend into the main plot area
'major_tick_out = 6'
'major_tick_line_color = black'
'major_tick_line_alpha = 1.0'
'major_tick_line_cap = butt'
'major_tick_line_dash = []'
'major_tick_line_dash_offset = 0'
'major_tick_line_join = bevel'
'major_tick_line_width = 1'
# -  -  -  -  -  -  -  -
'minor_tick_in = 0' # The distance in pixels that minor ticks should extend into the main plot area
'minor_tick_out = 4'
'minor_tick_line_color = black'
'minor_tick_line_alpha = 1.0'
'minor_tick_line_cap = butt'
'minor_tick_line_dash = []'
'minor_tick_line_dash_offset = 0'
'minor_tick_line_join = bevel'
'minor_tick_line_width = 1'
# -  -  -  -  -  -  -  -
'axis_line_color = black'
'axis_line_alpha = 1.0'
'axis_line_cap = butt'
'axis_line_dash = []'
'axis_line_dash_offset = 0'
'axis_line_join = bevel'

'axis_line_width = 1'
'visible = True'

# %% [markdown]
# #### Style the title

# %%
# figure().title:: Attributes 
title = f.title

'text = '
'text_font = helvetica'
'text_font_size = 13px'
'text_font_style = bold'
# -  -  -  -  -  -  -  - 
'text_color = #444444'
'text_alpha = 1.0'
# -  -  -  -  -  -  -  - 
'align = left'
'vertical_align = bottom'
'text_line_height = 1.0'
# -  -  -  -  -  -  -  - 
'offset = 0'
'standoff = 10'
# -  -  -  -  -  -  -  - 
'background_fill_color = None'
'background_fill_alpha = 1.0'
# -  -  -  -  -  -  -  - 
'border_line_color = None'
'border_line_alpha = 1.0'
'border_line_cap = butt'
'border_line_dash = []'
'border_line_dash_offset = 0'
'border_line_join = bevel'
'border_line_color = None'
'border_line_width = 1'

# %% [markdown]
# #### Style the legend

# %%
# figure().legend:: Attributes 
# Style the legend #IMPORTANT: .circle(... legend_label="Create Legend first!")
# IMPORTANT! 3.03 - legend(x) -> legend_label(o)
f.circle(legend_label = "Create Legend first to set legend attrs!")

leg = f.legend


'location = top_right'
# 3.03 - ('top_left', 'top_center', 'top_right', 'center_left', 'center_center', 'center_right', 'bottom_left', 'bottom_center', 'bottom_right', 'top', 'left', 'center', 'right', 'bottom') or Tuple:(Float, Float)


'orientation = vertical'
'title = None'
'title_text_color = #444444'
'title_text_alpha = 1.0'
'title_text_align = left'
'title_text_font = helvetica'
'title_text_font_size = 13px'
'title_text_font_style = italic'
'title_text_baseline = bottom'
'title_text_line_height = 1.2'
'title_standoff = 5'
'label_text_color = #444444'
'label_text_alpha = 1.0'
'label_text_align = left'
'label_text_font = helvetica'
'label_text_font_size = 13px'
'label_text_font_style = normal'
'label_text_baseline = middle'
'label_text_line_height = 1.2'
'label_standoff = 5'
'label_height = 20'
'label_width = 20'
'background_fill_color = #ffffff'
'background_fill_alpha = 0.95'
'border_line_color = #e5e5e5'
'border_line_alpha = 0.5'
'border_line_cap = butt'
'border_line_dash = []'
'border_line_dash_offset = 0'
'border_line_join = bevel'
'border_line_width = 1'
'inactive_fill_color = white'
'inactive_fill_alpha = 0.7'
'click_policy = none'
'glyph_height = 20'
'glyph_width = 20'
'margin = 10' #	Amount of margin (in pixels) around the outside of the color bar.
'padding = 10' #  the blank space surrounding the content within the legend (The bigger, the bigger size of legend rectangle) 
'spacing = 3'
"items = [LegendItem(id='p1418', ...)]"

# %% [markdown]
# #### Style the grid

# %%
# figure().grid:: Attributes
# Style the Grid
xgri = f.xgrid
ygri = f.ygrid
gri = f.grid


'dimension = [0, 1]'
"bounds = ['auto', 'auto']"
"axis = [LinearAxis(id='p1358', ...), LinearAxis(id='p1365', ...)]"
'ticker = [None, None]'
# -  -  -  -  -  -  -  - 
"grid_line_color = ['#e5e5e5', '#e5e5e5']"
'grid_line_alpha = [1.0, 1.0]'
"grid_line_cap = ['butt', 'butt']"
'grid_line_dash = [[], []]'
'grid_line_dash_offset = [0, 0]'
"grid_line_join = ['bevel', 'bevel']"
'grid_line_width = [1, 1]'
# -  -  -  -  -  -  -  - 
'minor_grid_line_color = [None, None]'
'minor_grid_line_alpha = [1.0, 1.0]'
"minor_grid_line_cap = ['butt', 'butt']"
'minor_grid_line_dash = [[], []]'         # [dash size, dash interval], eg. [5,3]
'minor_grid_line_dash_offset = [0, 0]'
"minor_grid_line_join = ['bevel', 'bevel']"
'minor_grid_line_width = [1, 1]'
# -  -  -  -  -  -  -  - 
'band_fill_color = [None, None]'
'band_fill_alpha = [0, 0]'
# -  -  -  -  -  -  -  - 
"band_hatch_color = ['black', 'black']"
'band_hatch_alpha = [1.0, 1.0]'
'band_hatch_pattern = [None, None]'
'band_hatch_weight = [1.0, 1.0]'
'band_hatch_scale = [12.0, 12.0]'
'band_hatch_extra = [{}, {}]'

# %% [markdown]
# #### Style the Hover Tools

# %%
'hover = HoverTool(tooltips=)'
"""
hover.tooltips = [
                    ("index", "$index"),
                    ("(x,y)", "($x, $y)"),
                    ("radius", "@radius"),
                    ("fill color", "$color[hex, swatch]:fill_color"),
                    ("fill color", "$color[hex]:fill_color"),
                    ("fill color", "$color:fill_color"),
                    ("fill color", "$swatch:fill_color"),
                    ("foo", "@foo"),
                    ("bar", "@bar"),
                    ("baz", "@baz{safe}"),
                    ("total", "@total{$0,0.00}")
                ]
"""
tooltips = """
<div>
    <div>
        <img
            src="@imgs" height="42" alt="@imgs" width="42"
            style="float: left; margin: 0px 15px 15px 0px;"
            border="2"
            ></img>
    </div>
    <div>
        <span style="font-size: 15px; font-weight: bold;"
        >@species</span>
    </div>
    <div>
        <span style="font-size: 10px; color: #696;">Petal Length: @petal_length</span><br>
        <span style="font-size: 10px; color: #696;">Petal Width: @petal_width</span><br>
    </div>
<div>
"""

# %% [markdown]
# #### Span

# %%
from bokeh.models import Span
from bokeh.layouts import gridplot

f = figure()

'apply_theme = <function HasProps.apply_theme at 0x7f5b1c3bbe20>',
'coordinates = Nullable(Instance(CoordinateMapping))',
"dataspecs = <bound method HasProps.dataspecs of <class 'bokeh.modelsannotations.geometry.Span'>>",
"descriptors = <bound method HasProps.descriptors of <class 'bokeh.modelsannotations.geometry.Span'>>",
'destroy = <function Model.destroy at 0x7f5b1c2a2480>',
"dimension = Enum('width', 'height')",
'document = <property object at 0x7f5b1c2b8900>',
'equals = <function HasProps.equals at 0x7f5b1c3bb1a0>',
'group = Nullable(Instance(RendererGroup))',
'id = <property object at 0x7f5b1c293c40>',
'js_event_callbacks = Dict(String, List(Instance(Callback)))',
'js_link = <function Model.js_link at 0x7f5b1c2a2840>',
'js_on_change = <function Model.js_on_change at 0x7f5b1c2a28e0>',
'js_on_event = <function Model.js_on_event at 0x7f5b1c2a27a0>',
'js_property_callbacks = Dict(String, List(Instance(Callback)))',
"level = Enum('image', 'underlay', 'glyph', 'guide', 'annotation', 'overlay')",
'line_alpha = Alpha',
"line_cap = Enum('butt', 'round', 'square')",
'line_color = Nullable(Color)',
'line_dash = DashPattern',
'line_dash_offset = Int',
"line_join = Enum('miter', 'round', 'bevel')",
'line_width = Float',
'location = Nullable(Float)',
"location_units = Enum('canvas', 'screen', 'data')",
"lookup = <bound method HasProps.lookup of <class 'bokeh.models.annotationsgeometry.Span'>>",
'name = Nullable(String)',
'on_change = <function Model.on_change at 0x7f5b1c2a2980>',
'on_event = <function EventCallbackManager.on_event at 0x7f5b1c2a1300>',
"parameters = <bound method Model.parameters of <class 'bokeh.modelsannotations.geometry.Span'>>",
"properties = <bound method HasProps.properties of <class 'bokeh.modelsannotations.geometry.Span'>>",
"properties_with_refs = <bound method HasProps.properties_with_refs of <class'bokeh.models.annotations.geometry.Span'>>",
'properties_with_values = <function HasProps.properties_with_values at0x7f5b1c3bb7e0>',
'query_properties_with_values = <function HasProps.query_properties_with_valuesat 0x7f5b1c3bbce0>',
'ref = <property object at 0x7f5b429a4db0>',
'references = <function Model.references at 0x7f5b1c2a2a20>',
'remove_on_change = <function PropertyCallbackManager.remove_on_change at0x7f5b1c2a1620>',
'select = <function Model.select at 0x7f5b1c2a2ac0>',
'select_one = <function Model.select_one at 0x7f5b1c2a2b60>',
'set_from_json = <function HasProps.set_from_json at 0x7f5b1c3bb2e0>',
'set_select = <function Model.set_select at 0x7f5b1c2a2c00>',
'subscribed_events = Set(String)',
'syncable = Bool',
'tags = List(AnyRef)',
'themed_values = <function HasProps.themed_values at 0x7f5b1c3bbd80>',
'to_serializable = <function Model.to_serializable at 0x7f5b1c2a2ca0>',
'trigger = <function Model.trigger at 0x7f5b1c2a2d40>',
'unapply_theme = <function HasProps.unapply_theme at 0x7f5b1c3bbec0>',
'update = <function HasProps.update at 0x7f5b1c3bb380>',
'visible = Bool',
'x_range_name = String',
'y_range_name = String'

# f.add_layout(Span(...))
# f = gridplot([[f1, f2],
#                f3, f4]])

# %% [markdown]
# #### BoxAnnotation

# %%
from bokeh.models import BoxAnnotation

'apply_theme = <function HasProps.apply_theme at 0x7f5b1c3bbe20>',

'bottom = None',

'bottom_units = None',

'coordinates = Nullable(Instance(CoordinateMapping))',

"dataspecs = <bound method HasProps.dataspecs of <class 'bokeh.models.annotations.geometry.Span'>>",

"descriptors = <bound method HasProps.descriptors of <class 'bokeh.models.annotations.geometry.Span'>>",

'destroy = <function Model.destroy at 0x7f5b1c2a2480>',

'document = <property object at 0x7f5b1c2b8900>',

'equals = <function HasProps.equals at 0x7f5b1c3bb1a0>',

'fill_alpha = None',

'fill_color = None',

'group = Nullable(Instance(RendererGroup))',

'hatch_alpha = None',

'hatch_color = None',

'hatch_extra = None',

'hatch_pattern = None',

'hatch_scale = None',

'hatch_weight = None',

'id = <property object at 0x7f5b1c293c40>',

'js_event_callbacks = Dict(String, List(Instance(Callback)))',

'js_link = <function Model.js_link at 0x7f5b1c2a2840>',

'js_on_change = <function Model.js_on_change at 0x7f5b1c2a28e0>',

'js_on_event = <function Model.js_on_event at 0x7f5b1c2a27a0>',

'js_property_callbacks = Dict(String, List(Instance(Callback)))',

'left = None',

'left_units = None',

"level = Enum('image', 'underlay', 'glyph', 'guide', 'annotation', 'overlay')",

'line_alpha = Alpha',

"line_cap = Enum('butt', 'round', 'square')",

'line_color = Nullable(Color)',

'line_dash = DashPattern',

'line_dash_offset = Int',

"line_join = Enum('miter', 'round', 'bevel')",

'line_width = Float',

"lookup = <bound method HasProps.lookup of <class 'bokeh.models.annotations.geometry.Span'>>",

'name = Nullable(String)',

'on_change = <function Model.on_change at 0x7f5b1c2a2980>',

'on_event = <function EventCallbackManager.on_event at 0x7f5b1c2a1300>',

"parameters = <bound method Model.parameters of <class 'bokeh.models.annotations.geometry.Span'>>",

"properties = <bound method HasProps.properties of <class 'bokeh.models.annotations.geometry.Span'>>",

"properties_with_refs = <bound method HasProps.properties_with_refs of <class 'bokeh.models.annotations.geometry.Span'>>",

'properties_with_values = <function HasProps.properties_with_values at 0x7f5b1c3bb7e0>',

'query_properties_with_values = <function HasProps.query_properties_with_values at 0x7f5b1c3bbce0>',

'ref = <property object at 0x7f5b429a4db0>',

'references = <function Model.references at 0x7f5b1c2a2a20>',

'remove_on_change = <function PropertyCallbackManager.remove_on_change at 0x7f5b1c2a1620>',

'right = None',

'right_units = None',

'select = <function Model.select at 0x7f5b1c2a2ac0>',

'select_one = <function Model.select_one at 0x7f5b1c2a2b60>',

'set_from_json = <function HasProps.set_from_json at 0x7f5b1c3bb2e0>',

'set_select = <function Model.set_select at 0x7f5b1c2a2c00>',

'subscribed_events = Set(String)',

'syncable = Bool',

'tags = List(AnyRef)',

'themed_values = <function HasProps.themed_values at 0x7f5b1c3bbd80>',

'to_serializable = <function Model.to_serializable at 0x7f5b1c2a2ca0>',

'top = None',

'top_units = None',

'trigger = <function Model.trigger at 0x7f5b1c2a2d40>',

'unapply_theme = <function HasProps.unapply_theme at 0x7f5b1c3bbec0>',

'update = <function HasProps.update at 0x7f5b1c3bb380>',

'visible = Bool',

'x_range_name = String',

'y_range_name = String'

# f.add_layout(BoxAnnotation(...))
# f = gridplot([[f1, f2],
#                f3, f4]])

# %%
from bokeh.models.annotations import Label, LabelSet

"angle = AngleSpec(units_default='rad')",

"angle_units = NotSerialized(Enum('deg', 'rad', 'grad', 'turn'))",

'apply_theme = <function HasProps.apply_theme at 0x7ffd4a17f7e0>',

'background_fill_alpha = AlphaSpec(String, Float, Instance(Value), Instance(Field), Instance(Expr), Struct(value=Float, transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)), Struct(expr=Instance(Expression), transform=Instance(Transform)))',

'background_fill_color = ColorSpec(String, Nullable(Color), Instance(Value), Instance(Field), Instance(Expr), Struct(value=Nullable(Color), transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)), Struct(expr=Instance(Expression), transform=Instance(Transform)))',

'border_line_alpha = AlphaSpec(String, Float, Instance(Value), Instance(Field), Instance(Expr), Struct(value=Float, transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)), Struct(expr=Instance(Expression), transform=Instance(Transform)))',

"border_line_cap = LineCapSpec(String, Enum('butt', 'round', 'square'), Instance(Value), Instance(Field), Instance(Expr), Struct(value=Enum('butt', 'round', 'square'), transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)), Struct(expr=Instance(Expression), transform=Instance(Transform)))",

'border_line_color = ColorSpec(String, Nullable(Color), Instance(Value), Instance(Field), Instance(Expr), Struct(value=Nullable(Color), transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)), Struct(expr=Instance(Expression), transform=Instance(Transform)))',

'border_line_dash = DashPatternSpec(String, DashPattern, Instance(Value), Instance(Field), Instance(Expr), Struct(value=DashPattern, transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)), Struct(expr=Instance(Expression), transform=Instance(Transform)))',

'border_line_dash_offset = IntSpec(String, Int, Instance(Value), Instance(Field), Instance(Expr), Struct(value=Int, transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)), Struct(expr=Instance(Expression), transform=Instance(Transform)))',

"border_line_join = LineJoinSpec(String, Enum('miter', 'round', 'bevel'), Instance(Value), Instance(Field), Instance(Expr), Struct(value=Enum('miter', 'round', 'bevel'), transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)), Struct(expr=Instance(Expression), transform=Instance(Transform)))",

'border_line_width = NumberSpec(String, Float, Instance(Value), Instance(Field), Instance(Expr), Struct(value=Float, transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)), Struct(expr=Instance(Expression), transform=Instance(Transform)))',

'coordinates = Nullable(Instance(CoordinateMapping))',

"dataspecs = <bound method HasProps.dataspecs of <class 'bokeh.models.annotations.labels.LabelSet'>>",

"descriptors = <bound method HasProps.descriptors of <class 'bokeh.models.annotations.labels.LabelSet'>>",

'destroy = <function Model.destroy at 0x7ffd2e265ee0>',

'document = <property object at 0x7ffd2e25f560>',

'equals = <function HasProps.equals at 0x7ffd4a17eb60>',

'group = Nullable(Instance(RendererGroup))',

'id = <property object at 0x7ffd2e25e8e0>',

'js_event_callbacks = Dict(String, List(Instance(Callback)))',

'js_link = <function Model.js_link at 0x7ffd2e2662a0>',

'js_on_change = <function Model.js_on_change at 0x7ffd2e266340>',

'js_on_event = <function Model.js_on_event at 0x7ffd2e266200>',

'js_property_callbacks = Dict(String, List(Instance(Callback)))',

"level = Enum('image', 'underlay', 'glyph', 'guide', 'annotation', 'overlay')",

"lookup = <bound method HasProps.lookup of <class 'bokeh.models.annotations.labels.LabelSet'>>",

'name = Nullable(String)',

'on_change = <function Model.on_change at 0x7ffd2e2663e0>',

'on_event = <function EventCallbackManager.on_event at 0x7ffd2e264d60>',

"parameters = <bound method Model.parameters of <class 'bokeh.models.annotations.labels.LabelSet'>>",

"properties = <bound method HasProps.properties of <class 'bokeh.models.annotations.labels.LabelSet'>>",

"properties_with_refs = <bound method HasProps.properties_with_refs of <class 'bokeh.models.annotations.labels.LabelSet'>>",

'properties_with_values = <function HasProps.properties_with_values at 0x7ffd4a17f1a0>',

'query_properties_with_values = <function HasProps.query_properties_with_values at 0x7ffd4a17f6a0>',

'ref = <property object at 0x7ffd72abb830>',

'references = <function Model.references at 0x7ffd2e266480>',

'remove_on_change = <function PropertyCallbackManager.remove_on_change at 0x7ffd2e265080>',

'select = <function Model.select at 0x7ffd2e266520>',

'select_one = <function Model.select_one at 0x7ffd2e2665c0>',

'set_from_json = <function HasProps.set_from_json at 0x7ffd4a17eca0>',

'set_select = <function Model.set_select at 0x7ffd2e266660>',

'source = Instance(DataSource)',

'subscribed_events = Set(String)',

'syncable = Bool',

'tags = List(AnyRef)',

'text = NullStringSpec(String, Nullable(String), Instance(Value), Instance(Field), Instance(Expr), Struct(value=Nullable(String), transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)), Struct(expr=Instance(Expression), transform=Instance(Transform)))',

"text_align = TextAlignSpec(String, Enum('left', 'right', 'center'), Instance(Value), Instance(Field), Instance(Expr), Struct(value=Enum('left', 'right', 'center'), transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)), Struct(expr=Instance(Expression), transform=Instance(Transform)))",

'text_alpha = AlphaSpec(String, Float, Instance(Value), Instance(Field), Instance(Expr), Struct(value=Float, transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)), Struct(expr=Instance(Expression), transform=Instance(Transform)))',

"text_baseline = TextBaselineSpec(String, Enum('top', 'middle', 'bottom', 'alphabetic', 'hanging', 'ideographic'), Instance(Value), Instance(Field), Instance(Expr), Struct(value=Enum('top', 'middle', 'bottom', 'alphabetic', 'hanging', 'ideographic'), transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)), Struct(expr=Instance(Expression), transform=Instance(Transform)))",

'text_color = ColorSpec(String, Nullable(Color), Instance(Value), Instance(Field), Instance(Expr), Struct(value=Nullable(Color), transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)), Struct(expr=Instance(Expression), transform=Instance(Transform)))',

'text_font = StringSpec(String, String, Instance(Value), Instance(Field), Instance(Expr), Struct(value=String, transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)), Struct(expr=Instance(Expression), transform=Instance(Transform)))',

'text_font_size = FontSizeSpec(String, FontSize, Instance(Value), Instance(Field), Instance(Expr), Struct(value=FontSize, transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)), Struct(expr=Instance(Expression), transform=Instance(Transform)))',

"text_font_style = FontStyleSpec(String, Enum('normal', 'italic', 'bold', 'bold italic'), Instance(Value), Instance(Field), Instance(Expr), Struct(value=Enum('normal', 'italic', 'bold', 'bold italic'), transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)), Struct(expr=Instance(Expression), transform=Instance(Transform)))",

'text_line_height = NumberSpec(String, Float, Instance(Value), Instance(Field), Instance(Expr), Struct(value=Float, transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)), Struct(expr=Instance(Expression), transform=Instance(Transform)))',

'text_outline_color = ColorSpec(String, Nullable(Color), Instance(Value), Instance(Field), Instance(Expr), Struct(value=Nullable(Color), transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)), Struct(expr=Instance(Expression), transform=Instance(Transform)))',

'themed_values = <function HasProps.themed_values at 0x7ffd4a17f740>',

'to_serializable = <function Model.to_serializable at 0x7ffd2e266700>',

'trigger = <function Model.trigger at 0x7ffd2e2667a0>',

'unapply_theme = <function HasProps.unapply_theme at 0x7ffd4a17f880>',

'update = <function HasProps.update at 0x7ffd4a17ed40>',

'visible = Bool',

'x = NumberSpec(String, Float, Instance(Value), Instance(Field), Instance(Expr), Struct(value=Float, transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)), Struct(expr=Instance(Expression), transform=Instance(Transform)))',

'x_offset = NumberSpec(String, Float, Instance(Value), Instance(Field), Instance(Expr), Struct(value=Float, transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)), Struct(expr=Instance(Expression), transform=Instance(Transform)))',

'x_range_name = String',

"x_units = Enum('canvas', 'screen', 'data')",

'y = NumberSpec(String, Float, Instance(Value), Instance(Field), Instance(Expr), Struct(value=Float, transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)), Struct(expr=Instance(Expression), transform=Instance(Transform)))',

'y_offset = NumberSpec(String, Float, Instance(Value), Instance(Field), Instance(Expr), Struct(value=Float, transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)), Struct(expr=Instance(Expression), transform=Instance(Transform)))',

'y_range_name = String',

"y_units = Enum('canvas', 'screen', 'data')"


# f.add_layout(LabelSet(x=,
#                       y=,
#                       text=,
#                       x_offset=5,
#                       y_offset=5)...)
# f = gridplot([[f1, f2],
#                f3, f4]])

# %% [markdown]
# #### Extracting figure attrs

# %%
from bokeh.plotting import figure
from bokeh.io import output_file, output_notebook, show
from bokeh.sampledata.iris import flowers
from bokeh.models import Range1d, PanTool, ResetTool, HoverTool

# Create the figure object
f = figure()

attrs = """x_range,
x_scale,
extra_x_ranges,
extra_x_scales,
y_range,
y_scale,
extra_y_ranges,
extra_y_scales,
title_location,
width,
height,
background_fill_color,
background_fill_alpha,
border_fill_color,
border_fill_alpha,
frame_width,
frame_height,
inner_width,
inner_height,
outer_width,
outer_height,
outline_line_color,
outline_line_alpha,
outline_line_cap,
outline_line_dash,
outline_line_dash_offset,
outline_line_join,
outline_line_width,
min_border,
min_border_top,
min_border_bottom,
min_border_left,
min_border_right,
renderers,
left,
right,
above,
below,
center,
hidpi,
tools,
toolbar,
toolbar_location,
toolbar_sticky,
lod_factor,
lod_threshold,
lod_timeout,
output_backend,
match_aspect,
aspect_scale,
reset_policy""".split(',\n')

### The vars() function only returns the attributes of an object that are defined in the object's __dict__ attribute. Some attributes in the Bokeh library, such as the outer_height attribute, are not stored in the __dict__ attribute, but are instead properties that are dynamically generated by Bokeh.
vars(f)


### To see all the attributes and properties of a Bokeh Figure object, you can use the dir() function, which returns a list of all the attributes and properties, including those that are not stored in the __dict__ attribute.
dir(f)


var_dict = dict()
for attr in dir(f):
    value = getattr(f, attr, None)
    var_dict[attr] = value


[ attr+' = '+str(var_dict.get(attr)) for attr in attrs ]

# %% [markdown]
# #### Extracting figure.title attrs

# %%
# figure().title:: Attributes 
title = f.title

attrs = """text
text_font
text_font_size
text_font_style
text_color
text_alpha
align
vertical_align
text_line_height
offset
standoff
background_fill_color
background_fill_alpha
border_line_color
border_line_alpha
border_line_cap
border_line_dash
border_line_dash_offset
border_line_join
border_line_color
border_line_width""".split('\n')

var_dict = dict()
for attr in dir(f.title):
    value = getattr(f.title, attr, None)
    var_dict[attr] = value


[ attr+' = '+str(var_dict.get(attr)) for attr in attrs ]

# %% [markdown]
# #### Extracting figure.axes attrs

# %%
# figure.axis:: Attributes
x = f.xaxis  # x-axis
y = f.yaxis  # y-axis
z = f.axis   # x,y axes


attrs = """bounds
ticker
formatter
axis_label
axis_label_standoff
axis_label_text_color
axis_label_text_alpha
axis_label_text_align
axis_label_text_font
axis_label_text_font_size
axis_label_text_font_style
axis_label_text_line_height
major_label_orientation
major_label_overrides
major_label_policy
major_label_text_color
major_label_text_alpha
major_label_text_font
major_label_text_font_size
major_label_text_font_style
major_label_text_baseline
major_label_text_align
major_label_text_line_height
major_tick_in
major_tick_out
major_tick_line_color
major_tick_line_alpha
major_tick_line_cap
major_tick_line_dash
major_tick_line_dash_offset
major_tick_line_join
major_tick_line_width
minor_tick_in
minor_tick_out
minor_tick_line_color
minor_tick_line_alpha
minor_tick_line_cap
minor_tick_line_dash
minor_tick_line_dash_offset
minor_tick_line_join
minor_tick_line_width
axis_line_color
axis_line_alpha
axis_line_cap
axis_line_dash
axis_line_dash_offset
axis_line_join
axis_line_width
visible""".split('\n')


var_dict = dict()
for attr in dir(f.xaxis):
    value = getattr(f.xaxis, attr, None)
    var_dict[attr] = value

[ attr+' = '+str(var_dict.get(attr)) for attr in attrs]

# %% [markdown]
# #### Extracting figure.legend attrs

# %%
f.circle(legend_label = "Create Legend first to set legend attrs!")

# figure().legend:: Attributes 
# Style the legend #IMPORTANT: .circle(... legend_label="Create Legend first!")
leg = f.legend

attrs = """location
orientation
title
title_text_color
title_text_alpha
title_text_align
title_text_font
title_text_font_size
title_text_font_style
title_text_baseline
title_text_line_height
title_standoff
label_text_color
label_text_alpha
label_text_align
label_text_font
label_text_font_size
label_text_font_style
label_text_baseline
label_text_line_height
label_standoff
label_height
label_width
background_fill_color
background_fill_alpha
border_line_color
border_line_alpha
border_line_cap
border_line_dash
border_line_dash_offset
border_line_join
border_line_width
inactive_fill_color
inactive_fill_alpha
click_policy
glyph_height
glyph_width
margin
padding
spacing
items""".split('\n')

var_dict = dict()
for attr in dir(f.legend):
    value = getattr(f.legend, attr, None)
    var_dict[attr] = value

[ attr+' = '+str(var_dict.get(attr)) for attr in attrs]

# %% [markdown]
# #### Extracting figure.grid attrs

# %%
# figure().grid:: Attributes
# Style the Grid
xgri = f.xgrid
ygri = f.ygrid
gri = f.grid


attrs = """dimension
bounds
axis
ticker
grid_line_color
grid_line_alpha
grid_line_cap
grid_line_dash
grid_line_dash_offset
grid_line_join
grid_line_width
minor_grid_line_color
minor_grid_line_alpha
minor_grid_line_cap
minor_grid_line_dash
minor_grid_line_dash_offset
minor_grid_line_join
minor_grid_line_width
band_fill_color
band_fill_alpha
band_hatch_color
band_hatch_alpha
band_hatch_pattern
band_hatch_weight
band_hatch_scale
band_hatch_extra""".split('\n')

var_dict = dict()
for attr in dir(f.grid):
    value = getattr(f.grid, attr, None)
    var_dict[attr] = value

[ attr+' = '+str(var_dict.get(attr)) for attr in attrs]

# %%
from bokeh.models import Span

attrs =  ['apply_theme',
 'coordinates',
 'dataspecs',
 'descriptors',
 'destroy',
 'dimension',
 'document',
 'equals',
 'group',
 'id',
 'js_event_callbacks',
 'js_link',
 'js_on_change',
 'js_on_event',
 'js_property_callbacks',
 'level',
 'line_alpha',
 'line_cap',
 'line_color',
 'line_dash',
 'line_dash_offset',
 'line_join',
 'line_width',
 'location',
 'location_units',
 'lookup',
 'name',
 'on_change',
 'on_event',
 'parameters',
 'properties',
 'properties_with_refs',
 'properties_with_values',
 'query_properties_with_values',
 'ref',
 'references',
 'remove_on_change',
 'select',
 'select_one',
 'set_from_json',
 'set_select',
 'subscribed_events',
 'syncable',
 'tags',
 'themed_values',
 'to_serializable',
 'trigger',
 'unapply_theme',
 'update',
 'visible',
 'x_range_name',
 'y_range_name']


var_dict = dict()
for attr in dir(Span):
    value = getattr(Span, attr, None)
    var_dict[attr] = value


[ attr+' = '+str(var_dict.get(attr)) for attr in attrs ]
# Out:
# ['apply_theme = <function HasProps.apply_theme at 0x7ffd4a17f7e0>',
#  'coordinates = Nullable(Instance(CoordinateMapping))',
#  "dataspecs = <bound method HasProps.dataspecs of <class 'bokeh.models.annotations.geometry.Span'>>",
#  "descriptors = <bound method HasProps.descriptors of <class 'bokeh.models.annotations.geometry.Span'>>",
#  'destroy = <function Model.destroy at 0x7ffd2e265ee0>',
#  "dimension = Enum('width', 'height')",
#  'document = <property object at 0x7ffd2e25f560>',
#  'equals = <function HasProps.equals at 0x7ffd4a17eb60>',
#  'group = Nullable(Instance(RendererGroup))',
#  'id = <property object at 0x7ffd2e25e8e0>',
#  'js_event_callbacks = Dict(String, List(Instance(Callback)))',
#  'js_link = <function Model.js_link at 0x7ffd2e2662a0>',
#  'js_on_change = <function Model.js_on_change at 0x7ffd2e266340>',
#  'js_on_event = <function Model.js_on_event at 0x7ffd2e266200>',
#  'js_property_callbacks = Dict(String, List(Instance(Callback)))',
# ...

# %%
from bokeh.models.annotations import Label, LabelSet

attrs = [ 'angle',
 'angle_units',
 'apply_theme',
 'background_fill_alpha',
 'background_fill_color',
 'border_line_alpha',
 'border_line_cap',
 'border_line_color',
 'border_line_dash',
 'border_line_dash_offset',
 'border_line_join',
 'border_line_width',
 'coordinates',
 'dataspecs',
 'descriptors',
 'destroy',
 'document',
 'equals',
 'group',
 'id',
 'js_event_callbacks',
 'js_link',
 'js_on_change',
 'js_on_event',
 'js_property_callbacks',
 'level',
 'lookup',
 'name',
 'on_change',
 'on_event',
 'parameters',
 'properties',
 'properties_with_refs',
 'properties_with_values',
 'query_properties_with_values',
 'ref',
 'references',
 'remove_on_change',
 'select',
 'select_one',
 'set_from_json',
 'set_select',
 'source',
 'subscribed_events',
 'syncable',
 'tags',
 'text',
 'text_align',
 'text_alpha',
 'text_baseline',
 'text_color',
 'text_font',
 'text_font_size',
 'text_font_style',
 'text_line_height',
 'text_outline_color',
 'themed_values',
 'to_serializable',
 'trigger',
 'unapply_theme',
 'update',
 'visible',
 'x',
 'x_offset',
 'x_range_name',
 'x_units',
 'y',
 'y_offset',
 'y_range_name',
 'y_units']

var_dict = dict()
for attr in dir(LabelSet):
    value = getattr(LabelSet, attr, None)
    var_dict[attr] = value


[ attr+' = '+str(var_dict.get(attr)) for attr in attrs ]
# Out:
# ["angle = AngleSpec(units_default='rad')",
#  "angle_units = NotSerialized(Enum('deg', 'rad', 'grad', 'turn'))",
#  'apply_theme = <function HasProps.apply_theme at 0x7ffd4a17f7e0>',
#  'background_fill_alpha = AlphaSpec(String, Float, Instance(Value), Instance(Field), Instance(Expr), Struct(value=Float, transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)), Struct(expr=Instance(Expression), transform=Instance(Transform)))',
#  'background_fill_color = ColorSpec(String, Nullable(Color), Instance(Value), Instance(Field), Instance(Expr), Struct(value=Nullable(Color), transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)), Struct(expr=Instance(Expression), transform=Instance(Transform)))',
# ...
